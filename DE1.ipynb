# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://dharani.telangana.gov.in/knowLandStatus")
soup = BeautifulSoup(r.text, "html.parser")
#print(soup.text)

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

'selenium.webdriver.support.select.Select'

from selenium.webdriver.support.select import Select

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# !pip install selenium
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
import time

# %%
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
# import Action chains 
from selenium.webdriver.common.action_chains import ActionChains
 
# import KEYS
from selenium.webdriver.common.keys import Keys
 
print("please enter the index value/serial number of District \n")    
d = input()
print("please enter the index value/serial number of Mandal \n")
m = input()
print("please enter the index value/serial number of Village \n")
v = input()
    
# create webdriver object
driver = webdriver.Chrome()
 
# get geeksforgeeks.org
#driver.get("https://way2sms.com/login")
driver.get("https://dharani.telangana.gov.in/knowLandStatus")

dist = Select(driver.find_element(By.ID,"districtID"))

#dist.send_keys("Adilabad|ఆదిలాబాద్")
dist.select_by_index(d) #"Adilabad|ఆదిలాబాద్"
# create action chain object
#action = ActionChains(driver)
time.sleep(5)
mandal= Select(driver.find_element(By.ID,"mandalID"))

mandal.select_by_index(m)
# perform the operation
#action.key_down(Keys.CONTROL).send_keys('F').key_up(Keys.CONTROL).perform()
time.sleep(5)
vill=Select(driver.find_element(By.ID,"villageId"))

vill.select_by_index(v)
#element = driver.find_element(By.ID,"name")
#element.send_keys(" DSA")
time.sleep(7)
#from selenium import webdriver
from selenium.webdriver.common.by import By
#set chromodriver.exe path
#driver = webdriver.Chrome()
#driver.implicitly_wait(0.5)
#launch URL
#driver.get("https://dharani.telangana.gov.in/knowLandStatus")
#Select class for dropdown
l = driver.find_element(By.ID, "surveyIdselect")
#l.send_keys('ChromeDriver')

#l.submit()
#l= driver.find_element_by_name("selType")
d= Select(l)
print('\n Survey numbers are: \n')
#iterate over dropdown options
for opt in d.options:
#get option text
   print(opt.text)
#dropdown = driver.find_element(By.ID,"district_ID")
#s= d.select_by_index(5)
#print(s)
#browser quit
driver.quit()
# Out:
# please enter the index value/serial number of District
#
# 5
# please enter the index value/serial number of Mandal
#
# 6
# please enter the index value/serial number of Village
#
# 3
#
#  Survey numbers are:
#
# Please select
# 1/A
# 1/B
# 1/C/1
# 1/C/2
# 2/A/1/1
# 2/A/1/2
# 2/A/2
# 2/A/3
# 2/B
# 3/A
# 3/B
# 3/C
# 3/D
# 4/1
# 4/2
# 5/A/1
# 5/A/2
# 5/B
# 6/A
# 6/B
# 7/10/1
# 7/10/2
# 7/1/1
# 7/1/2
# 7/13
# 7/14/2
# 7/15/1/1
# 7/15/1/2
# 7/15/2
# 7/16
# 7/2
# 7/3
# 7/4
# 7/6/1
# 7/6/2
# 7/7
# 7/8
# 7/9
# 8/A
# 8/B
# 8/C/2
# 8/D
# 8/E
# 9/A
# 9/B
# 9/C
# 9/D
# 9/E
# 9/F
# 10/B
# 10/B/3
# 10/C
# 10/D
# 10/E
# 10/F
# 10/G
# 10/H
# 11/A/1
# 11/A/2/1
# 11/A/2/2
# 11/A/3
# 11/A/4/2
# 11/A/4/3
# 11/B
# 11/B/6
# 12/A/2
# 12/B
# 12/D
# 12/E
# 12/F
# 12/G
# 12/H
# 12/I
# 12/J
# 12/K
# 12/L
# 13/B
# 13/C
# 13/D
# 13/E
# 13/F
# 14/A
# 14/B
# 14/D
# 14/E
# 14/F
# 14/G
# 14/H
# 15/B
# 15/C/1
# 15/C/2
# 15/C/3
# 15/C/4
# 16/A
# 16/B/1
# 16/B/2
# 17/A/1/1
# 17/A/1/2
# 17/A/2
# 17/B/1
# 17/B/2
# ...
